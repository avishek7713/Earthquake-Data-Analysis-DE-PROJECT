# %% [markdown]
# **Importing the necessary libraries like requests, json, date and timedelta**

# %%
# import requests
# import json
# from datetime import date, timedelta
# Out:
# StatementMeta(, 8f217d7b-5133-4522-b493-f48dc6dc8cd7, 5, Finished, Available, Finished)

# %% [markdown]
# **Stating the Start and End date for the data to be fetched. The start date is 7 days prior to today's date and end date is 1 day prior**

# %% [markdown]
# # Fetching the data

# %%
# Construct the API URL with start and end dates provided by the Data Factory, formatted for geojson output

url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"
# Out:
# StatementMeta(, 8f217d7b-5133-4522-b493-f48dc6dc8cd7, 10, Finished, Available, Finished)

# %%
# Make the GET request to fetch the data

response = requests.get(url)
# Out:
# StatementMeta(, 8f217d7b-5133-4522-b493-f48dc6dc8cd7, 11, Finished, Available, Finished)

# %%
# Check if the request was successful

if response.status_code == 200:
    # Get the JSON response
    data = response.json()
    data = data["features"]

    # Specify the file name (and file path if needed)
    file_path = f'/lakehouse/default/Files/{start_date}_earthquake_data.json'

    # Open the file in write mode ('w') and save the JSON data
    with open(file_path, 'w') as file:
        # The `json.dump` method serializes `data` as a JSON formatted stream to `file`
        # `indent=4` makes the file human-readable by adding white space
        json.dump(data, file, indent = 4)
    
    print(f"Data successfully saved to {file_path}")
else:
    print(f"Failed to fetch data. Status Code: {response.status_code}")
# Out:
# StatementMeta(, 8f217d7b-5133-4522-b493-f48dc6dc8cd7, 12, Finished, Available, Finished)
# Data successfully saved to /lakehouse/default/Files/2025-02-19_earthquake_data.json

# %%
df = spark.read.option("multiline", "true").json("Files/2025-02-19_earthquake_data.json")
# df now is a Spark DataFrame containing JSON data from "Files/2025-02-19_earthquake_data.json".
# Out:
# StatementMeta(, 8f217d7b-5133-4522-b493-f48dc6dc8cd7, 14, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b19f1389-fa9e-43fc-a13b-adfc273d63d2)
