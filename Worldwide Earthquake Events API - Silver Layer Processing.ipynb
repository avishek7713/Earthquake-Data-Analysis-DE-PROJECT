# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
# Out:
# StatementMeta(, fa9adcc3-9562-443f-b9ec-0e0ab9be349b, 3, Finished, Available, Finished)

# %%
# df now is a Spark Dataframe containing JSON data

df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, fa9adcc3-9562-443f-b9ec-0e0ab9be349b, 6, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, fa9adcc3-9562-443f-b9ec-0e0ab9be349b, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ba7d23f6-135c-486e-aa5a-d5428b20e7f7)

# %%
# Reshape earthquake data by extracting and renaming key attributes for further analysis

df = df.select(
    'id',
    col('geometry.coordinates').getItem(0).alias('longitude'),
    col('geometry.coordinates').getItem(1).alias('latitude'),
    col('geometry.coordinates').getItem(2).alias('elevation'),
    col('properties.title').alias('title'),
    col('properties.place').alias('place_description'),
    col('properties.sig').alias('sig'),
    col('properties.mag').alias('mag'),
    col('properties.magType').alias('magType'),
    col('properties.time').alias('time'),
    col('properties.updated').alias('updated')
)
# Out:
# StatementMeta(, fa9adcc3-9562-443f-b9ec-0e0ab9be349b, 8, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, fa9adcc3-9562-443f-b9ec-0e0ab9be349b, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 80f5a5fd-d8ca-4d8b-a3aa-71c28da68b7b)

# %%
# Convert 'time' and 'updated' columns from milliseconds to timestamp format for clearer datatime representation

df = df.withColumn('time', col('time')/1000)\
        .withColumn('updated', col('updated')/1000)\
        .withColumn('time', col('time').cast(TimestampType()))\
        .withColumn('updated', col('updated').cast(TimestampType()))
# Out:
# StatementMeta(, fa9adcc3-9562-443f-b9ec-0e0ab9be349b, 10, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, fa9adcc3-9562-443f-b9ec-0e0ab9be349b, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 95bfd277-965d-4cb3-aa56-ffae869ff731)

# %%
# Appending the data to the gold table
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, fa9adcc3-9562-443f-b9ec-0e0ab9be349b, 12, Finished, Available, Finished)
